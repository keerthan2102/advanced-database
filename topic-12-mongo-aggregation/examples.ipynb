# %%
import pymongo
from bson.objectid import ObjectId
import sys

# client = MongitaClientDisk()
try:
  client = pymongo.MongoClient("mongodb+srv://supervisor:supervisor123@cluster0.agji2kq.mongodb.net/?appName=Cluster0")
  print("connected.")
  
# return a friendly error if a URI error is thrown 
except pymongo.errors.ConfigurationError:
  print("An Invalid URI host error was received. Is your Atlas host name correct in your connection string?")
  sys.exit(1)
# Out:
# connected.

# %%
from pprint import pprint

# %%
pets_db = client.pets_db
pets_collection = pets_db.pets_collection
kind_collection = pets_db.kind_collection
pets = list(pets_collection.find())

pprint([pet for pet in pets])
# Out:
# [{'_id': ObjectId('69121e1ee9e02c322d8745e4'),
#   'age': 3,
#   'kind_id': ObjectId('69121e1ee9e02c322d8745e1'),
#   'name': 'Suzy',
#   'owner': 'Greg'},
#  {'_id': ObjectId('69121e1ee9e02c322d8745e5'),
#   'age': 2,
#   'kind_id': ObjectId('69121e1ee9e02c322d8745e2'),
#   'name': 'Sandy',
#   'owner': 'Steve'},
#  {'_id': ObjectId('69121e1ee9e02c322d8745e6'),
#   'age': 1,
#   'kind_id': ObjectId('69121e1ee9e02c322d8745e1'),
#   'name': 'Dorothy',
#   'owner': 'Elizabeth'},
#  {'_id': ObjectId('69121e1ee9e02c322d8745e7'),
#   'age': 4,
#   'kind_id': ObjectId('69121e1ee9e02c322d8745e1'),
#   'name': 'Heidi',
#   'owner': 'David'}]

# %%
pets = pets_collection.aggregate([
    {
    "$lookup":{
        "from": "kind_collection",
        "localField": "kind_id",
        "foreignField": "_id",
        "as": "kind_info"
    }
    }
])
pprint([pet for pet in pets])
# Out:
# [{'_id': ObjectId('69121e1ee9e02c322d8745e4'),
#   'age': 3,
#   'kind_id': ObjectId('69121e1ee9e02c322d8745e1'),
#   'kind_info': [{'_id': ObjectId('69121e1ee9e02c322d8745e1'),
#                  'food': 'Dog food',
#                  'id': '69121e1ee9e02c322d8745e1',
#                  'kind_name': 'Dog',
#                  'noise': 'Bark'}],
#   'name': 'Suzy',
#   'owner': 'Greg'},
#  {'_id': ObjectId('69121e1ee9e02c322d8745e5'),
#   'age': 2,
#   'kind_id': ObjectId('69121e1ee9e02c322d8745e2'),
#   'kind_info': [{'_id': ObjectId('69121e1ee9e02c322d8745e2'),
#                  'food': 'Cat food',
#                  'kind_name': 'Cat',
#                  'noise': 'Meow'}],
#   'name': 'Sandy',
#   'owner': 'Steve'},
#  {'_id': ObjectId('69121e1ee9e02c322d8745e6'),
#   'age': 1,
#   'kind_id': ObjectId('69121e1ee9e02c322d8745e1'),
#   'kind_info': [{'_id': ObjectId('69121e1ee9e02c322d8745e1'),
#                  'food': 'Dog food',
# ...

# %%
pets = pets_collection.aggregate([
    {
        "$lookup":{
            "from": "kind_collection",
            "localField": "kind_id",
            "foreignField": "_id",
            "as": "kind_info"
        }
    },
    {
        "$unwind":"$kind_info" 
    }
])
pprint([pet for pet in pets])
# Out:
# [{'_id': ObjectId('69121e1ee9e02c322d8745e4'),
#   'age': 3,
#   'kind_id': ObjectId('69121e1ee9e02c322d8745e1'),
#   'kind_info': {'_id': ObjectId('69121e1ee9e02c322d8745e1'),
#                 'food': 'Dog food',
#                 'id': '69121e1ee9e02c322d8745e1',
#                 'kind_name': 'Dog',
#                 'noise': 'Bark'},
#   'name': 'Suzy',
#   'owner': 'Greg'},
#  {'_id': ObjectId('69121e1ee9e02c322d8745e5'),
#   'age': 2,
#   'kind_id': ObjectId('69121e1ee9e02c322d8745e2'),
#   'kind_info': {'_id': ObjectId('69121e1ee9e02c322d8745e2'),
#                 'food': 'Cat food',
#                 'kind_name': 'Cat',
#                 'noise': 'Meow'},
#   'name': 'Sandy',
#   'owner': 'Steve'},
#  {'_id': ObjectId('69121e1ee9e02c322d8745e6'),
#   'age': 1,
#   'kind_id': ObjectId('69121e1ee9e02c322d8745e1'),
#   'kind_info': {'_id': ObjectId('69121e1ee9e02c322d8745e1'),
#                 'food': 'Dog food',
#                 'id': '69121e1ee9e02c322d8745e1',
# ...

# %%
pets = pets_collection.aggregate([
    {
        "$lookup":{
            "from": "kind_collection",
            "localField": "kind_id",
            "foreignField": "_id",
            "as": "kind_info"
        }
    },
    {
        "$unwind":"$kind_info" 
    },
    {
        "$project":{
            "_id":1,
            "name":1,
            "owner":1,
            "age":1,
            "noise":"$kind_info.noise",
            "kind_name":"$kind_info.kind_name",
            "food":"$kind_info.food",
            "random_number":"42",
        }
    }
])
pprint([pet for pet in pets])
# Out:
# [{'_id': ObjectId('69121e1ee9e02c322d8745e4'),
#   'age': 3,
#   'food': 'Dog food',
#   'kind_name': 'Dog',
#   'name': 'Suzy',
#   'noise': 'Bark',
#   'owner': 'Greg',
#   'random_number': '42'},
#  {'_id': ObjectId('69121e1ee9e02c322d8745e5'),
#   'age': 2,
#   'food': 'Cat food',
#   'kind_name': 'Cat',
#   'name': 'Sandy',
#   'noise': 'Meow',
#   'owner': 'Steve',
#   'random_number': '42'},
#  {'_id': ObjectId('69121e1ee9e02c322d8745e6'),
#   'age': 1,
#   'food': 'Dog food',
#   'kind_name': 'Dog',
#   'name': 'Dorothy',
#   'noise': 'Bark',
#   'owner': 'Elizabeth',
#   'random_number': '42'},
#  {'_id': ObjectId('69121e1ee9e02c322d8745e7'),
#   'age': 4,
#   'food': 'Dog food',
#   'kind_name': 'Dog',
#   'name': 'Heidi',
#   'noise': 'Bark',
#   'owner': 'David',
#   'random_number': '42'}]

# %%
pets = pets_collection.aggregate([
    {
        "$lookup":{
            "from": "kind_collection",
            "localField": "kind_id",
            "foreignField": "_id",
            "as": "kind_info"
        }
    },
    {
        "$unwind":"$kind_info" 
    },
    {
        "$project":{
            "_id":1,
            "name":1,
            "owner":1,
            "age":1,
            "noise":"$kind_info.noise",
            "kind_name":"$kind_info.kind_name",
            "food":"$kind_info.food",
            "random_number":"42",
            "category": { "$cond": {"if": {"$lt":["$age",3]}, "then": "young", "else":"adult" }}
        }
    }
])
pprint([pet for pet in pets])
# Out:
# [{'_id': ObjectId('69121e1ee9e02c322d8745e4'),
#   'age': 3,
#   'category': 'adult',
#   'food': 'Dog food',
#   'kind_name': 'Dog',
#   'name': 'Suzy',
#   'noise': 'Bark',
#   'owner': 'Greg',
#   'random_number': '42'},
#  {'_id': ObjectId('69121e1ee9e02c322d8745e5'),
#   'age': 2,
#   'category': 'young',
#   'food': 'Cat food',
#   'kind_name': 'Cat',
#   'name': 'Sandy',
#   'noise': 'Meow',
#   'owner': 'Steve',
#   'random_number': '42'},
#  {'_id': ObjectId('69121e1ee9e02c322d8745e6'),
#   'age': 1,
#   'category': 'young',
#   'food': 'Dog food',
#   'kind_name': 'Dog',
#   'name': 'Dorothy',
#   'noise': 'Bark',
#   'owner': 'Elizabeth',
#   'random_number': '42'},
#  {'_id': ObjectId('69121e1ee9e02c322d8745e7'),
#   'age': 4,
#   'category': 'adult',
#   'food': 'Dog food',
#   'kind_name': 'Dog',
#   'name': 'Heidi',
#   'noise': 'Bark',
#   'owner': 'David',
#   'random_number': '42'}]
